# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="uwbLCWSnHV2geuphu3jv")
project = rf.workspace("deneme-nq1dn").project("chicken-invasion-detection-zqoa3")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 22.5 MB/s eta 0:00:00
# ...

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
from ultralytics import RTDETR

model = RTDETR("rtdetr-l.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
results = model.train(
    data="/content/dataset/data.yaml",
    epochs=50,
    imgsz=640,
    batch=8
)
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
metrics = model.val(
    data="/content/dataset/data.yaml",
    split="test"
)

print(metrics)
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# rt-detr-l summary: 310 layers, 32,004,290 parameters, 0 gradients, 103.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 9.3±4.6 MB/s, size: 10.8 KB)
# val: Scanning /content/dataset/test/labels... 208 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 208/208 1.4Kit/s 0.2s
# val: New cache created: /content/dataset/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.1s/it 14.1s
#                    all        208       2898      0.866      0.853      0.865      0.559
#       buff_chicken_leg         97        657      0.933      0.924      0.937      0.596
#           buff_powerup          9         10      0.837        0.7      0.702      0.392
#           chicken_boss         15         15      0.932      0.911      0.935        0.7
# ...

# %%
from ultralytics import RTDETR

model = RTDETR("/content/runs/detect/train2/weights/best.pt")

# %%
import os
import random

test_images_path = "/content/dataset/test/images"

image_list = os.listdir(test_images_path)
random_image = random.choice(image_list)

image_path = os.path.join(test_images_path, random_image)

print("Test edilen görüntü:", image_path)
# Out:
# Test edilen görüntü: /content/dataset/test/images/Chicken-Invaders-1-ALL-WAVES-LEVELS-100-walkthrough-_frame_00372_jpg.rf.f09fefd5a94977250eb137a24f6bd150.jpg

# %%
results = model.predict(
    source=image_path,
    conf=0.25,
    save=True
)
# Out:
# image 1/1 /content/dataset/test/images/Chicken-Invaders-1-ALL-WAVES-LEVELS-100-walkthrough-_frame_00372_jpg.rf.f09fefd5a94977250eb137a24f6bd150.jpg: 640x640 6 buff_chicken_legs, 22 chicken_minions, 1 egg, 1 ship, 66.4ms
# Speed: 8.1ms preprocess, 66.4ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict

# %%
from IPython.display import Image

Image(filename="/content/runs/detect/predict/" + random_image)

# %%
import shutil

# Kaynak (train2 içindeki best.pt)
source = "/content/runs/detect/train2/weights/best.pt"

# Hedef klasör (örnek: /content/models/)
destination = "/content/models/best.pt"

shutil.copy(source, destination)
print("Model kaydedildi:", destination)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_534/3738893575.py in <cell line: 0>()
#       7 destination = "/content/models/best.pt"
#       8
# ----> 9 shutil.copy(source, destination)
#      10 print("Model kaydedildi:", destination)
#
# /usr/lib/python3.12/shutil.py in copy(src, dst, follow_symlinks)
#     433     if os.path.isdir(dst):
#     434         dst = os.path.join(dst, os.path.basename(src))
# --> 435     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     436     copymode(src, dst, follow_symlinks=follow_symlinks)
#     437     return dst
#
# /usr/lib/python3.12/shutil.py in copyfile(src, dst, follow_symlinks)
#     260         with open(src, 'rb') as fsrc:
#     261             try:
# --> 262                 with open(dst, 'wb') as fdst:
#     263                     # macOS
#     264                     if _HAS_FCOPYFILE:
#
# ...

# %%
from google.colab import files

files.download("/content/runs/detect/train2/weights/best.pt")
